# %%
import pandas as pd 
movies=pd.read_csv('movies.csv')

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
import pandas as pd 
rating=pd.read_csv('ratings.csv')
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
import pandas as pd 
tags=pd.read_csv('tags.csv')
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
import pandas as pd 
links=pd.read_csv('ratings.csv')
links
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movie_rating1= pd.merge(movies,rating ,on=['movieId'],how='inner')
movie_rating1
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
movie_rating2 = pd.merge(movies,rating,on=['movieId'],how='left')
movie_rating2
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
movie_rating3 = pd.merge(movies,rating,on=['movieId'],how='right')
movie_rating3
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             3         Grumpier Old Men (1995)
# 2             6                     Heat (1995)
# 3            47     Seven (a.k.a. Se7en) (1995)
# 4            50      Usual Suspects, The (1995)
# ...         ...                             ...
# 100831   166534                    Split (2017)
# 100832   168248   John Wick: Chapter Two (2017)
# 100833   168250                  Get Out (2017)
# 100834   168252                    Logan (2017)
# 100835   170875  The Fate of the Furious (2017)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1                                    Comedy|Romance       1     4.0
# 2                             Action|Crime|Thriller       1     4.0
# 3                                  Mystery|Thriller       1     5.0
# ...

# %%
movie_rating_tags = pd.merge(movie_rating1,tags,on=['userId'],how='inner')
movie_rating_tags
# Out:
#          movieId_x                                title  \
# 0                1                     Toy Story (1995)
# 1               50           Usual Suspects, The (1995)
# 2               58    Postman, The (Postino, Il) (1994)
# 3              150                     Apollo 13 (1995)
# 4              165    Die Hard: With a Vengeance (1995)
# ...            ...                                  ...
# 4626861     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626862     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626863     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626864     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4626865     193587  Bungo Stray Dogs: Dead Apple (2018)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       7     4.5
# 1                             Crime|Mystery|Thriller       7     4.5
# 2                               Comedy|Drama|Romance       7     3.0
# ...

# %%
movie_rating_tags1 = pd.merge(movie_rating1,tags,on=['userId'],how='left')
movie_rating_tags1
# Out:
#          movieId_x                                title  \
# 0                1                     Toy Story (1995)
# 1                1                     Toy Story (1995)
# 2                1                     Toy Story (1995)
# 3                1                     Toy Story (1995)
# 4                1                     Toy Story (1995)
# ...            ...                                  ...
# 4706480     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4706481     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4706482     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4706483     193587  Bungo Stray Dogs: Dead Apple (2018)
# 4706484     193609  Andrew Dice Clay: Dice Rules (1991)
#
#                                               genres  userId  rating  \
# 0        Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1        Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# 2        Adventure|Animation|Children|Comedy|Fantasy       7     4.5
# ...

# %%
movie_rating_tags2= pd.merge(movie_rating1,tags,on=['userId'],how='right')
movie_rating_tags2
# Out:
#          movieId_x                             title  \
# 0              318  Shawshank Redemption, The (1994)
# 1              333                  Tommy Boy (1995)
# 2             1704          Good Will Hunting (1997)
# 3             3578                  Gladiator (2000)
# 4             6874          Kill Bill: Vol. 1 (2003)
# ...            ...                               ...
# 4626861     166534                      Split (2017)
# 4626862     168248     John Wick: Chapter Two (2017)
# 4626863     168250                    Get Out (2017)
# 4626864     168252                      Logan (2017)
# 4626865     170875    The Fate of the Furious (2017)
#
#                               genres  userId  rating  timestamp_x  movieId_y  \
# 0                        Crime|Drama       2     3.0   1445714835      60756
# 1                             Comedy       2     4.0   1445715029      60756
# 2                      Drama|Romance       2     4.5   1445715228      60756
# ...

# %%
print("(Rows,Columns) : " +str(movie_rating_tags1.shape))
movie_rating_tags1.columns
# Out:
# (Rows,Columns) : (4706485, 9)
# Index(['movieId_x', 'title', 'genres', 'userId', 'rating', 'timestamp_x',
#        'movieId_y', 'tag', 'timestamp_y'],
#       dtype='object')

# %%
movie_rating_tags1.describe()
# Out:
#           movieId_x        userId        rating   timestamp_x     movieId_y  \
# count  4.706485e+06  4.706485e+06  4.706485e+06  4.706485e+06  4.626866e+06
# mean   1.644222e+04  4.787287e+02  3.277587e+00  1.200256e+09  1.094841e+04
# std    3.170939e+04  1.024621e+02  9.352906e-01  1.915970e+08  2.611919e+04
# min    1.000000e+00  1.000000e+00  5.000000e-01  8.281246e+08  1.000000e+00
# 25%    1.955000e+03  4.740000e+02  3.000000e+00  1.062076e+09  9.240000e+02
# 50%    4.127000e+03  4.740000e+02  3.500000e+00  1.108735e+09  2.871000e+03
# 75%    7.789000e+03  4.770000e+02  4.000000e+00  1.457845e+09  6.400000e+03
# max    1.936090e+05  6.100000e+02  5.000000e+00  1.537799e+09  1.935650e+05
#
#         timestamp_y
# count  4.626866e+06
# mean   1.239233e+09
# std    1.592218e+08
# min    1.137179e+09
# 25%    1.137207e+09
# 50%    1.138033e+09
# 75%    1.457846e+09
# max    1.537099e+09
